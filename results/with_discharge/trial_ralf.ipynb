# %%
import pandas as pd

# %%
y_obs=pd.read_csv('y_obs.csv')
y_obs.set_index(y_obs.columns[0],inplace=True)
y_sim=pd.read_csv('y_sim.csv')
y_sim.set_index(y_sim.columns[0],inplace=True)

# %%
y_obs
# Out:
#             GRDC_6140100  GRDC_6140101  GRDC_6140120  GRDC_6140130  \
# Unnamed: 0
# 2006-01-01          2.65          3.02          4.95          1.18
# 2006-01-02          6.62          6.24          9.26          3.74
# 2006-01-03          8.17          7.87         12.85          6.67
# 2006-01-04          2.03          1.86          1.50          1.18
# 2006-01-05          1.48          1.21          1.02          0.77
# ...                  ...           ...           ...           ...
# 2020-12-27          0.03          0.03          0.02          0.02
# 2020-12-28          1.42          1.37          0.96          2.53
# 2020-12-29          1.98          2.07          0.38          1.83
# 2020-12-30          0.22          0.28          0.13          0.03
# 2020-12-31          0.02          0.02          0.01          0.04
#
#             GRDC_6140140  GRDC_6140150  GRDC_6140250  GRDC_6140280  \
# Unnamed: 0
# 2006-01-01          0.92          1.79          0.76          0.71
# ...

# %%
import matplotlib.pyplot as plt

# %%
basin_to_analyze = 'camelsgb_4001'
plt.plot(y_obs[basin_to_analyze],y_sim[basin_to_analyze],'o',alpha=0.1)
plt.xlim([0,70])
plt.ylim([0,70])
plt.plot(range(0,100),range(0,100))
